# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 让结果在notebook中显示
# %matplotlib inline
#设置绘图大小
plt.style.use({'figure.figsize':(25,20)})
plt.rcParams['font.sans-serif']=['SimHei'] #用来显示中文
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %% [markdown]
# ### 从本地导入数据文件

# %%
df=pd.read_csv('housing_all.csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.shape
# Out:
# (506, 14)

# %% [markdown]
# ### 探索数据结构

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null int64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.4 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %% [markdown]
# ### 数据可视化

# %%
plt.style.use({'figure.figsize':(15,10)})

# %%
df.hist(bins=15)#bins=15表示直方图分15个桶
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000188CBA22FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CDAEEF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CDB26128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CEB246D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000188CEB54C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CEB8D278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CEBBA7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CEBE9DA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000188CEBE9DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CEC4E908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CEC81EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CECBE4A8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000188CECEEA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CED2F048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CED5F5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188CED8FBA8>]],
#       dtype=object)

# %%
sns.pairplot(df)

# %%
df.plot()

# %%
df.plot(subplots=True,figsize=(20,45))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA5702E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA591080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA279438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA2AB898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA2DDCF8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA31E198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA34D5F8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA380A90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA380AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA3F0358>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA424780>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA455BE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA497080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000188DA4C64E0>],
#       dtype=object)

# %%
df.plot(kind='hist',bins=15)

# %%
sns.boxplot(data=df[['INDUS','RM','RAD','LSTAT']])
plt.title('波士顿房价数据集，一些特征的箱型图')
# Out:
# Text(0.5, 1.0, '波士顿房价数据集，一些特征的箱型图')

# %%
sns.violinplot(data=df[['INDUS','RM','RAD','LSTAT']])
plt.title('波士顿房价数据集，一些特征的小提琴图')
# Out:
# Text(0.5, 1.0, '波士顿房价数据集，一些特征的小提琴图')

# %%
sns.distplot(df['INDUS'])

# %%
sns.distplot(df['RM'])

# %%
sns.distplot(df['RAD'])

# %%
sns.distplot(df['MEDV'])

# %%
from scipy import stats
res=stats.probplot(df['MEDV'],plot=plt)

# %%
sns.heatmap(df.corr(),square=True,annot=True,cmap='YlGnBu')

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
for i in df.columns:
    plt.scatter(df[i],df['MEDV'])
    plt.title('{}与房价散点图'.format(i))
    plt.xlabel(i)
    plt.ylabel('MEDV')
    plt.yticks(range(0,60,5))
    plt.grid()
    plt.show()

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
y=df['MEDV']

# %%
drop_columns=['MEDV']
x=df.drop(drop_columns,axis=1)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
SelectKBest=SelectKBest(f_regression,k=3)#指定三个特征
bestFeature=SelectKBest.fit_transform(x,y)
SelectKBest.get_support()
x.columns[SelectKBest.get_support()]
# Out:
# Index(['RM', 'PTRATIO', 'LSTAT'], dtype='object')

# %%
sns.pairplot(df[['RM','PTRATIO','LSTAT','MEDV']])
